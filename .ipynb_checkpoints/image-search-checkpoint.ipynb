# %% [markdown]
# # Installation

# %%
# %pip install flickrapi
# Out:
# Collecting flickrapi
#   Downloading flickrapi-2.4.0-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: requests-oauthlib>=0.4.0 in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from flickrapi) (1.3.0)
# Requirement already satisfied: requests-toolbelt>=0.3.1 in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from flickrapi) (0.9.1)
# Requirement already satisfied: requests>=2.2.1 in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from flickrapi) (2.25.1)
# Requirement already satisfied: six>=1.5.2 in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from flickrapi) (1.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from requests>=2.2.1->flickrapi) (1.26.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from requests>=2.2.1->flickrapi) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from requests>=2.2.1->flickrapi) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from requests>=2.2.1->flickrapi) (2021.5.30)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from requests-oauthlib>=0.4.0->flickrapi) (3.1.1)
# Installing collected packages: flickrapi
# Successfully installed flickrapi-2.4.0
# WARNING: You are using pip version 21.1.2; however, version 21.3.1 is available.
# You should consider upgrading via the '/Users/macbookpro/opt/anaconda3/envs/tf2/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install ftfy regex tqdm
# %pip install git+https://github.com/openai/CLIP.git
# Out:
# Collecting ftfy
#   Downloading ftfy-6.0.3.tar.gz (64 kB)
#      |████████████████████████████████| 64 kB 5.2 MB/s eta 0:00:011
# Requirement already satisfied: regex in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (2020.6.8)
# Requirement already satisfied: tqdm in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (4.47.0)
# Requirement already satisfied: wcwidth in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from ftfy) (0.2.5)
# Building wheels for collected packages: ftfy
#   Building wheel for ftfy (setup.py) ... done
#   Created wheel for ftfy: filename=ftfy-6.0.3-py3-none-any.whl size=41934 sha256=9d42f2885fd2d4c3e2065e7865e67aa62ab645c014166d50d3b6247384665736
#   Stored in directory: /Users/macbookpro/Library/Caches/pip/wheels/ff/2a/24/75041425faf3347ab146a4a3d0484f723b2c44a7966a06e3f0
# Successfully built ftfy
# Installing collected packages: ftfy
# Successfully installed ftfy-6.0.3
# WARNING: You are using pip version 21.1.2; however, version 21.3.1 is available.
# You should consider upgrading via the '/Users/macbookpro/opt/anaconda3/envs/tf2/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /private/var/folders/9z/vxzd5t7x2vn4503l8w3td5pm0000gn/T/pip-req-build-sz58aa19
#   Running command git clone -q https://github.com/openai/CLIP.git /private/var/folders/9z/vxzd5t7x2vn4503l8w3td5pm0000gn/T/pip-req-build-sz58aa19
# Requirement already satisfied: ftfy in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from clip==1.0) (6.0.3)
# Requirement already satisfied: regex in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from clip==1.0) (2020.6.8)
# Requirement already satisfied: tqdm in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from clip==1.0) (4.47.0)
# Requirement already satisfied: torch in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from clip==1.0) (1.9.0)
# Requirement already satisfied: torchvision in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from clip==1.0) (0.10.0)
# Requirement already satisfied: wcwidth in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from ftfy->clip==1.0) (0.2.5)
# Requirement already satisfied: typing-extensions in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from torch->clip==1.0) (3.7.4.3)
# Requirement already satisfied: dataclasses in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from torch->clip==1.0) (0.8)
# Requirement already satisfied: pillow>=5.3.0 in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from torchvision->clip==1.0) (7.2.0)
# Requirement already satisfied: numpy in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from torchvision->clip==1.0) (1.19.5)
# Building wheels for collected packages: clip
#   Building wheel for clip (setup.py) ... done
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369409 sha256=0204f28a82032ce5079fd5499952cfadeae7b42e9211be2da26fbb1d6eaba3cc
#   Stored in directory: /private/var/folders/9z/vxzd5t7x2vn4503l8w3td5pm0000gn/T/pip-ephem-wheel-cache-vqrbip7m/wheels/41/36/e0/af6191bd08c254b17d779b05de8282c9ea81ef7048abbe290b
# Successfully built clip
# Installing collected packages: clip
# Successfully installed clip-1.0
# WARNING: You are using pip version 21.1.2; however, version 21.3.1 is available.
# You should consider upgrading via the '/Users/macbookpro/opt/anaconda3/envs/tf2/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade transformers==4.18.0
# Out:
# Collecting transformers==4.18.0
#   Downloading transformers-4.18.0-py3-none-any.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 7.1 MB/s eta 0:00:01
# Requirement already satisfied: packaging>=20.0 in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from transformers==4.18.0) (20.4)
# Requirement already satisfied: numpy>=1.17 in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from transformers==4.18.0) (1.19.5)
# Requirement already satisfied: tqdm>=4.27 in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from transformers==4.18.0) (4.47.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from transformers==4.18.0) (5.3.1)
# Requirement already satisfied: requests in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from transformers==4.18.0) (2.25.1)
# Requirement already satisfied: filelock in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from transformers==4.18.0) (3.0.12)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1.tar.gz (220 kB)
#      |████████████████████████████████| 220 kB 46.4 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: importlib-metadata in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from transformers==4.18.0) (4.5.0)
# Requirement already satisfied: dataclasses in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from transformers==4.18.0) (0.8)
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      |████████████████████████████████| 880 kB 37.9 MB/s eta 0:00:01
# Requirement already satisfied: regex!=2019.12.17 in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from transformers==4.18.0) (2020.6.8)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.4.0-py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 12.8 MB/s eta 0:00:01
# Collecting packaging>=20.0
#   Using cached packaging-21.3-py3-none-any.whl (40 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from huggingface-hub<1.0,>=0.1.0->transformers==4.18.0) (3.7.4.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from packaging>=20.0->transformers==4.18.0) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from importlib-metadata->transformers==4.18.0) (3.4.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from requests->transformers==4.18.0) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from requests->transformers==4.18.0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from requests->transformers==4.18.0) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from requests->transformers==4.18.0) (2021.5.30)
# Requirement already satisfied: six in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from sacremoses->transformers==4.18.0) (1.15.0)
# Requirement already satisfied: click in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from sacremoses->transformers==4.18.0) (7.1.2)
# Requirement already satisfied: joblib in /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages (from sacremoses->transformers==4.18.0) (0.16.0)
# Building wheels for collected packages: tokenizers, sacremoses
#   Building wheel for tokenizers (PEP 517) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/macbookpro/opt/anaconda3/envs/tf2/bin/python /Users/macbookpro/opt/anaconda3/envs/tf2/lib/python3.6/site-packages/pip/_vendor/pep517/in_process/_in_process.py build_wheel /var/folders/9z/vxzd5t7x2vn4503l8w3td5pm0000gn/T/tmpulmgh_b_
#        cwd: /private/var/folders/9z/vxzd5t7x2vn4503l8w3td5pm0000gn/T/pip-install-k77v3z4i/tokenizers_8b2d7cf4feb04828b7e1be5c749bcf57
#   Complete output (51 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.9-x86_64-3.6
#   creating build/lib.macosx-10.9-x86_64-3.6/tokenizers
#   copying py_src/tokenizers/__init__.py -> build/lib.macosx-10.9-x86_64-3.6/tokenizers
#   creating build/lib.macosx-10.9-x86_64-3.6/tokenizers/models
#   copying py_src/tokenizers/models/__init__.py -> build/lib.macosx-10.9-x86_64-3.6/tokenizers/models
#   creating build/lib.macosx-10.9-x86_64-3.6/tokenizers/decoders
#   copying py_src/tokenizers/decoders/__init__.py -> build/lib.macosx-10.9-x86_64-3.6/tokenizers/decoders
#   creating build/lib.macosx-10.9-x86_64-3.6/tokenizers/normalizers
#   copying py_src/tokenizers/normalizers/__init__.py -> build/lib.macosx-10.9-x86_64-3.6/tokenizers/normalizers
#   creating build/lib.macosx-10.9-x86_64-3.6/tokenizers/pre_tokenizers
#   copying py_src/tokenizers/pre_tokenizers/__init__.py -> build/lib.macosx-10.9-x86_64-3.6/tokenizers/pre_tokenizers
#   creating build/lib.macosx-10.9-x86_64-3.6/tokenizers/processors
#   copying py_src/tokenizers/processors/__init__.py -> build/lib.macosx-10.9-x86_64-3.6/tokenizers/processors
#   creating build/lib.macosx-10.9-x86_64-3.6/tokenizers/trainers
#   copying py_src/tokenizers/trainers/__init__.py -> build/lib.macosx-10.9-x86_64-3.6/tokenizers/trainers
#   creating build/lib.macosx-10.9-x86_64-3.6/tokenizers/implementations
#   copying py_src/tokenizers/implementations/byte_level_bpe.py -> build/lib.macosx-10.9-x86_64-3.6/tokenizers/implementations
#   copying py_src/tokenizers/implementations/sentencepiece_unigram.py -> build/lib.macosx-10.9-x86_64-3.6/tokenizers/implementations
#   copying py_src/tokenizers/implementations/sentencepiece_bpe.py -> build/lib.macosx-10.9-x86_64-3.6/tokenizers/implementations
#   copying py_src/tokenizers/implementations/base_tokenizer.py -> build/lib.macosx-10.9-x86_64-3.6/tokenizers/implementations
#   copying py_src/tokenizers/implementations/__init__.py -> build/lib.macosx-10.9-x86_64-3.6/tokenizers/implementations
#   copying py_src/tokenizers/implementations/char_level_bpe.py -> build/lib.macosx-10.9-x86_64-3.6/tokenizers/implementations
#   copying py_src/tokenizers/implementations/bert_wordpiece.py -> build/lib.macosx-10.9-x86_64-3.6/tokenizers/implementations
#   creating build/lib.macosx-10.9-x86_64-3.6/tokenizers/tools
#   copying py_src/tokenizers/tools/__init__.py -> build/lib.macosx-10.9-x86_64-3.6/tokenizers/tools
#   copying py_src/tokenizers/tools/visualizer.py -> build/lib.macosx-10.9-x86_64-3.6/tokenizers/tools
#   copying py_src/tokenizers/__init__.pyi -> build/lib.macosx-10.9-x86_64-3.6/tokenizers
#   copying py_src/tokenizers/models/__init__.pyi -> build/lib.macosx-10.9-x86_64-3.6/tokenizers/models
#   copying py_src/tokenizers/decoders/__init__.pyi -> build/lib.macosx-10.9-x86_64-3.6/tokenizers/decoders
#   copying py_src/tokenizers/normalizers/__init__.pyi -> build/lib.macosx-10.9-x86_64-3.6/tokenizers/normalizers
#   copying py_src/tokenizers/pre_tokenizers/__init__.pyi -> build/lib.macosx-10.9-x86_64-3.6/tokenizers/pre_tokenizers
#   copying py_src/tokenizers/processors/__init__.pyi -> build/lib.macosx-10.9-x86_64-3.6/tokenizers/processors
#   copying py_src/tokenizers/trainers/__init__.pyi -> build/lib.macosx-10.9-x86_64-3.6/tokenizers/trainers
#   copying py_src/tokenizers/tools/visualizer-styles.css -> build/lib.macosx-10.9-x86_64-3.6/tokenizers/tools
#   running build_ext
#   running build_rust
#   error: can't find Rust compiler
#
#   If you are using an outdated pip version, it is possible a prebuilt wheel is available for this package but pip is not able to install from it. Installing from the wheel would avoid the need for a Rust compiler.
#
#   To update pip, run:
#
#       pip install --upgrade pip
#
#   and then retry package installation.
#
#   If you did intend to build this package from source, try installing a Rust compiler from your system package manager and ensure it is on the PATH during installation. Alternatively, rustup (available at https://rustup.rs) is the recommended way to download and update the Rust compiler toolchain.
#   ----------------------------------------
#   ERROR: Failed building wheel for tokenizers
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895259 sha256=e197fe0d859111b3cfaf39cb0d4433bdc83919b27ff4f53d460107285f4062f6
#   Stored in directory: /Users/macbookpro/Library/Caches/pip/wheels/4c/64/31/e9900a234b23fb3e9dc565d6114a9d6ff84a72dbdd356502b4
# Successfully built sacremoses
# Failed to build tokenizers
# ERROR: Could not build wheels for tokenizers which use PEP 517 and cannot be installed directly
# WARNING: You are using pip version 21.1.2; however, version 21.3.1 is available.
# You should consider upgrading via the '/Users/macbookpro/opt/anaconda3/envs/tf2/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Download Images

# %%
from PIL import Image
import flickrapi
import requests

# Replace with your own API key and secret
api_key = '937c5fb63a6d88a2a148aec387c14272'
api_secret = 'b21c82310caf7c0f'

# Initialize the Flickr API client
flickr = flickrapi.FlickrAPI(api_key, api_secret, format='parsed-json')

# Use the 'flickr.photos.search' method to search for photos
# Here, we're searching for photos tagged with 'cat'
result = flickr.photos.search(tags='fashion')

# Extract the URLs of the photos
photo_urls = []
for photo in result['photos']['photo']:
    url = f"https://farm{photo['farm']}.staticflickr.com/{photo['server']}/{photo['id']}_{photo['secret']}.jpg"
    photo_urls.append(url)

# Print the list of URLs
print(photo_urls)
# Out:
# ['https://farm66.staticflickr.com/65535/52754000013_038e7ceab5.jpg', 'https://farm66.staticflickr.com/65535/52753807230_e7425d1646.jpg', 'https://farm66.staticflickr.com/65535/52753620139_19f7ef09fd.jpg', 'https://farm66.staticflickr.com/65535/52752835642_2bfe44e656.jpg', 'https://farm66.staticflickr.com/65535/52753448389_b5981b7ed3.jpg', 'https://farm66.staticflickr.com/65535/52753597448_3774815deb.jpg', 'https://farm66.staticflickr.com/65535/52752542027_dc0430820e.jpg', 'https://farm66.staticflickr.com/65535/52
g', 'https://farm66.staticflickr.com/65535/52750213805_533b0f6649.jpg', 'https://farm66.staticflickr.com/65535/52750213393_084d4d4463.jpg', 'https://farm66.staticflickr.com/65535/52749178732_385ff27c5d.jpg', 'https://farm66.staticflickr.com/65535/52749619679_2654f25b15.jpg', 'https://farm66.staticflickr.com/65535/52749829723_2028e8bd7e.jpg', 'https://farm66.staticflickr.com/65535/52749305686_a078d725bf.jpg', 'https://farm66.staticflickr.com/65535/52749616073_99f1017bc8.jpg', 'https://farm66.staticflickr.com/65535/52748564842_6eb889306b.jpg', 'https://farm66.staticflickr.com/65535/52749093726_f9ca408018.jpg', 'https://farm66.staticflickr.com/65535/52749186849_dfd0 ...

# %%
images = []
urls = []

for url in photo_urls:
  try:
    images.append(Image.open(requests.get(url, stream=True).raw))
    urls.append(url)
  except:
    # print(f'{url} does not exist')
    pass

# %%
import torch
import clip
from PIL import Image
import requests
from io import BytesIO
import numpy as np
from transformers import CLIPProcessor, CLIPModel

# Get model
device = "cuda" if torch.cuda.is_available() else "cpu"
model, preprocess = clip.load("ViT-B/32", device=device)

# Download the images and preprocess them
images = []
for url in urls:
    response = requests.get(url)
    img = Image.open(BytesIO(response.content))
    img = preprocess(img)
    images.append(img)

# Stack the preprocessed images into a batch
batch = torch.stack(images)

text = clip.tokenize(["a diagram", "a dog", "a cat"]).to(device)

with torch.no_grad():
    image_features = model.encode_image(batch)
    text_features = model.encode_text(text)
    
    # Print the shape of the embeddings tensor
    print(image_features.shape)

    logits_per_image, logits_per_text = model(batch, text)
    probs = logits_per_image.softmax(dim=-1).cpu().numpy()
# Out:
# torch.Size([100, 512])

# %%
import transformers

transformers.__version__
# Out:
# '4.18.0'

# %%
len(urls), len(images)
# Out:
# (100, 100)

# %% [markdown]
# # Elasticsearch

# %%
# %%capture

# %pip install elasticsearch==7.8.1
# %apt install default-jdk > /dev/null

# %%
try:
  import os
  import elasticsearch
  from elasticsearch import Elasticsearch
  import numpy as np
  import pandas as pd
  import sys
  import json
  from ast import literal_eval
  from tqdm import tqdm 
  import datetime
  from elasticsearch import helpers
  
except Exception as e:
  print(f"error: {e}")

# %%
# Download & extract Elasticsearch 7.0.0

# !wget https://artifacts.elastic.co/downloads/elasticsearch/elasticsearch-7.8.1-linux-x86_64.tar.gz -q
# !tar -xzf elasticsearch-7.8.1-linux-x86_64.tar.gz
# !chown -R daemon:daemon elasticsearch-7.8.1
# Out:
# chown: elasticsearch-7.8.1/bin/elasticsearch-syskeygen: Operation not permitted
# chown: elasticsearch-7.8.1/bin/elasticsearch-env: Operation not permitted
# chown: elasticsearch-7.8.1/bin/elasticsearch-env-from-file: Operation not permitted
# chown: elasticsearch-7.8.1/bin/elasticsearch-node: Operation not permitted
# chown: elasticsearch-7.8.1/bin/elasticsearch-saml-metadata: Operation not permitted
# chown: elasticsearch-7.8.1/bin/elasticsearch-keystore: Operation not permitted
# chown: elasticsearch-7.8.1/bin/elasticsearch-plugin: Operation not permitted
# chown: elasticsearch-7.8.1/bin/x-pack-env: Operation not permitted
# chown: elasticsearch-7.8.1/bin/elasticsearch-sql-cli: Operation not permitted
# chown: elasticsearch-7.8.1/bin/elasticsearch-shard: Operation not permitted
# chown: elasticsearch-7.8.1/bin/elasticsearch-setup-passwords: Operation not permitted
# chown: elasticsearch-7.8.1/bin/elasticsearch-migrate: Operation not permitted
# chown: elasticsearch-7.8.1/bin/elasticsearch-croneval: Operation not permitted
# chown: elasticsearch-7.8.1/bin/elasticsearch-certgen: Operation not permitted
# chown: elasticsearch-7.8.1/bin/elasticsearch-sql-cli-7.8.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/bin/elasticsearch-certutil: Operation not permitted
# chown: elasticsearch-7.8.1/bin/elasticsearch-users: Operation not permitted
# chown: elasticsearch-7.8.1/bin/elasticsearch-cli: Operation not permitted
# chown: elasticsearch-7.8.1/bin/x-pack-security-env: Operation not permitted
# chown: elasticsearch-7.8.1/bin/elasticsearch: Operation not permitted
# chown: elasticsearch-7.8.1/bin/x-pack-watcher-env: Operation not permitted
# chown: elasticsearch-7.8.1/bin: Operation not permitted
# chown: elasticsearch-7.8.1/config/jvm.options.d: Operation not permitted
# chown: elasticsearch-7.8.1/config/users_roles: Operation not permitted
# chown: elasticsearch-7.8.1/config/role_mapping.yml: Operation not permitted
# chown: elasticsearch-7.8.1/config/users: Operation not permitted
# chown: elasticsearch-7.8.1/config/elasticsearch.yml: Operation not permitted
# chown: elasticsearch-7.8.1/config/roles.yml: Operation not permitted
# chown: elasticsearch-7.8.1/config/log4j2.properties: Operation not permitted
# chown: elasticsearch-7.8.1/config/jvm.options: Operation not permitted
# chown: elasticsearch-7.8.1/config: Operation not permitted
# chown: elasticsearch-7.8.1/plugins: Operation not permitted
# chown: elasticsearch-7.8.1/README.asciidoc: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/man/man1/javap.1: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/man/man1/jdeprscan.1: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/man/man1/jpackage.1: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/man/man1/serialver.1: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/man/man1/jshell.1: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/man/man1/jstatd.1: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/man/man1/jdb.1: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/man/man1/jjs.1: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/man/man1/java.1: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/man/man1/keytool.1: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/man/man1/jmod.1: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/man/man1/jstat.1: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/man/man1/jcmd.1: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/man/man1/jfr.1: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/man/man1/jdeps.1: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/man/man1/jhsdb.1: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/man/man1/jconsole.1: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/man/man1/jar.1: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/man/man1/javadoc.1: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/man/man1/jstack.1: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/man/man1/jrunscript.1: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/man/man1/rmid.1: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/man/man1/jmap.1: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/man/man1/jaotc.1: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/man/man1/rmiregistry.1: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/man/man1/rmic.1: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/man/man1/jinfo.1: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/man/man1/jlink.1: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/man/man1/javac.1: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/man/man1/jps.1: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/man/man1/jarsigner.1: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/man/man1: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/man: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/bin/jarsigner: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/bin/jaotc: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/bin/rmic: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/bin/jfr: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/bin/rmid: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/bin/jdb: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/bin/jstack: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/bin/rmiregistry: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/bin/jar: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/bin/jcmd: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/bin/jrunscript: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/bin/jps: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/bin/java: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/bin/jhsdb: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/bin/javap: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/bin/jdeprscan: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/bin/javac: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/bin/keytool: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/bin/jmod: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/bin/jjs: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/bin/jmap: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/bin/jshell: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/bin/jstat: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/bin/jlink: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/bin/serialver: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/bin/javadoc: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/bin/jinfo: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/bin/jstatd: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/bin/jdeps: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/bin/jconsole: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/bin/jpackage: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/bin/jimage: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/bin: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/include/jawt.h: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/include/classfile_constants.h: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/include/jdwpTransport.h: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/include/jvmti.h: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/include/jni.h: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/include/linux/jni_md.h: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/include/linux/jawt_md.h: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/include/linux: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/include/jvmticmlr.h: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/include: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/release: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/libfontmanager.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/psfontj2d.properties: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/libverify.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/libjavajpeg.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/libmanagement_agent.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/jvm.cfg: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/security/public_suffix_list.dat: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/security/default.policy: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/security/blacklisted.certs: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/security/cacerts: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/security: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/jfr/default.jfc: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/jfr/profile.jfc: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/jfr: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/libjsound.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/libsunec.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/libsaproc.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/tzdb.dat: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/libmanagement_ext.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/libdt_socket.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/libprefs.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/server/libjvm.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/server/classes.jsa: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/server/libjsig.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/server: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/libjawt.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/libzip.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/libj2pcsc.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/libawt.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/ct.sym: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/libjaas.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/liblcms.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/libsplashscreen.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/libsctp.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/jrt-fs.jar: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/libjimage.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/libnet.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/libawt_headless.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/libextnet.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/libjsig.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/jspawnhelper: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/libattach.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/libj2gss.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/libawt_xawt.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/libnio.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/libinstrument.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/libjdwp.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/libjava.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/libmlib_image.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/libj2pkcs11.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/libfreetype.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/psfont.properties.ja: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/libjli.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/modules: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/libmanagement.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/classlist: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/jexec: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib/librmi.so: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/lib: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.management.rmi/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.management.rmi/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.management.rmi/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.management.rmi: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.unsupported.desktop/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.unsupported.desktop/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.unsupported.desktop/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.unsupported.desktop: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.scripting.nashorn.shell/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.scripting.nashorn.shell/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.scripting.nashorn.shell/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.scripting.nashorn.shell: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.internal.vm.compiler.management/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.internal.vm.compiler.management/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.internal.vm.compiler.management/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.internal.vm.compiler.management: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.se/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.se/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.se/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.se: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.security.jgss/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.security.jgss/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.security.jgss/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.security.jgss: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.jfr/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.jfr/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.jfr/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.jfr: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.management/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.management/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.management/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.management: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.security.sasl/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.security.sasl/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.security.sasl/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.security.sasl: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.net/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.net/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.net/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.net: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.jsobject/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.jsobject/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.jsobject/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.jsobject: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.rmic/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.rmic/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.rmic/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.rmic: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.zipfs/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.zipfs/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.zipfs/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.zipfs: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.dynalink/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.dynalink/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.dynalink/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.dynalink/dynalink.md: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.dynalink: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.compiler/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.compiler/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.compiler/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.compiler: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.xml/bcel.md: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.xml/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.xml/xalan.md: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.xml/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.xml/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.xml/dom.md: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.xml/jcup.md: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.xml/xerces.md: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.xml: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.jcmd/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.jcmd/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.jcmd/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.jcmd: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.naming.dns/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.naming.dns/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.naming.dns/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.naming.dns: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.instrument/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.instrument/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.instrument/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.instrument: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.localedata/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.localedata/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.localedata/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.localedata/cldr.md: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.localedata/thaidict.md: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.localedata: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.naming.rmi/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.naming.rmi/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.naming.rmi/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.naming.rmi: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.compiler/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.compiler/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.compiler/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.compiler: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.prefs/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.prefs/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.prefs/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.prefs: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.crypto.cryptoki/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.crypto.cryptoki/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.crypto.cryptoki/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.crypto.cryptoki/pkcs11wrapper.md: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.crypto.cryptoki/pkcs11cryptotoken.md: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.crypto.cryptoki: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.editpad/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.editpad/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.editpad/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.editpad: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.logging/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.logging/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.logging/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.logging: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.management/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.management/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.management/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.management: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.internal.vm.compiler/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.internal.vm.compiler/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.internal.vm.compiler/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.internal.vm.compiler: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.base/asm.md: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.base/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.base/public_suffix.md: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.base/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.base/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.base/cldr.md: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.base/icu.md: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.base/unicode.md: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.base/c-libutl.md: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.base/aes.md: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.base: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.net.http/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.net.http/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.net.http/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.net.http: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.internal.opt/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.internal.opt/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.internal.opt/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.internal.opt/jopt-simple.md: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.internal.opt: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.jconsole/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.jconsole/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.jconsole/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.jconsole: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.sql.rowset/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.sql.rowset/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.sql.rowset/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.sql.rowset: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.security.jgss/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.security.jgss/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.security.jgss/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.security.jgss: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.httpserver/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.httpserver/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.httpserver/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.httpserver: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.naming/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.naming/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.naming/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.naming: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.internal.jvmstat/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.internal.jvmstat/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.internal.jvmstat/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.internal.jvmstat: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.jartool/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.jartool/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.jartool/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.jartool: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.unsupported/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.unsupported/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.unsupported/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.unsupported: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.jdwp.agent/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.jdwp.agent/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.jdwp.agent/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.jdwp.agent: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.internal.le/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.internal.le/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.internal.le/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.internal.le/jline.md: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.internal.le: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.internal.ed/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.internal.ed/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.internal.ed/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.internal.ed: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.scripting/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.scripting/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.scripting/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.scripting: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.attach/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.attach/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.attach/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.attach: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.security.auth/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.security.auth/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.security.auth/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.security.auth: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.xml.dom/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.xml.dom/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.xml.dom/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.xml.dom: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.charsets/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.charsets/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.charsets/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.charsets: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.scripting.nashorn/joni.md: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.scripting.nashorn/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.scripting.nashorn/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.scripting.nashorn/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.scripting.nashorn/double-conversion.md: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.scripting.nashorn: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.sctp/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.sctp/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.sctp/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.sctp: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.rmi/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.rmi/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.rmi/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.rmi: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.smartcardio/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.smartcardio/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.smartcardio/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.smartcardio/pcsclite.md: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.smartcardio: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.jstatd/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.jstatd/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.jstatd/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.jstatd: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.transaction.xa/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.transaction.xa/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.transaction.xa/ASSEMBLY_EXCEPTION: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/java.transaction.xa: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.hotspot.agent/LICENSE: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk.hotspot.agent/ADDITIONAL_LICENSE_INFO: Operation not permitted
# chown: elasticsearch-7.8.1/jdk/legal/jdk
7.8.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/reindex/elasticsearch-ssl-config-7.8.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/reindex/httpclient-4.5.10.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/reindex/plugin-descriptor.properties: Operation not permitted
# chown: elasticsearch-7.8.1/modules/reindex/elasticsearch-rest-client-7.8.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/reindex/plugin-security.policy: Operation not permitted
# chown: elasticsearch-7.8.1/modules/reindex: Operation not permitted
# chown: elasticsearch-7.8.1/modules/lang-expression/asm-commons-5.0.4.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/lang-expression/antlr4-runtime-4.5.1-1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/lang-expression/asm-5.0.4.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/lang-expression/lang-expression-7.8.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/lang-expression/asm-tree-5.0.4.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/lang-expression/lucene-expressions-8.5.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/lang-expression/plugin-descriptor.properties: Operation not permitted
# chown: elasticsearch-7.8.1/modules/lang-expression/plugin-security.policy: Operation not permitted
# chown: elasticsearch-7.8.1/modules/lang-expression: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-watcher/jakarta.mail-1.6.4.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-watcher/owasp-java-html-sanitizer-20191001.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-watcher/failureaccess-1.0.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-watcher/guava-27.1-jre.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-watcher/jakarta.activation-1.2.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-watcher/NOTICE.txt: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-watcher/x-pack-watcher-7.8.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-watcher/LICENSE.txt: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-watcher/plugin-descriptor.properties: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-watcher/plugin-security.policy: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-watcher: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-identity-provider/opensaml-saml-api-3.4.5.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-identity-provider/guava-19.0.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-identity-provider/cryptacular-1.2.4.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-identity-provider/x-pack-identity-provider-7.8.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-identity-provider/opensaml-security-impl-3.4.5.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-identity-provider/slf4j-api-1.6.2.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-identity-provider/log4j-slf4j-impl-2.11.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-identity-provider/opensaml-messaging-api-3.4.5.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-identity-provider/httpclient-cache-4.5.10.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-identity-provider/opensaml-storage-impl-3.4.5.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-identity-provider/opensaml-storage-api-3.4.5.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-identity-provider/opensaml-soap-api-3.4.5.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-identity-provider/opensaml-profile-impl-3.4.5.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-identity-provider/opensaml-profile-api-3.4.5.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-identity-provider/xmlsec-2.1.4.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-identity-provider/opensaml-xmlsec-api-3.4.5.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-identity-provider/NOTICE.txt: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-identity-provider/opensaml-messaging-impl-3.4.5.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-identity-provider/opensaml-security-api-3.4.5.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-identity-provider/opensaml-saml-impl-3.4.5.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-identity-provider/metrics-core-3.2.2.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-identity-provider/opensaml-soap-impl-3.4.5.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-identity-provider/LICENSE.txt: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-identity-provider/opensaml-core-3.4.5.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-identity-provider/plugin-descriptor.properties: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-identity-provider/opensaml-xmlsec-impl-3.4.5.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-identity-provider/java-support-7.5.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-identity-provider/plugin-security.policy: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-identity-provider: Operation not permitted
# chown: elasticsearch-7.8.1/modules/lang-mustache/compiler-0.9.6.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/lang-mustache/lang-mustache-client-7.8.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/lang-mustache/plugin-descriptor.properties: Operation not permitted
# chown: elasticsearch-7.8.1/modules/lang-mustache/plugin-security.policy: Operation not permitted
# chown: elasticsearch-7.8.1/modules/lang-mustache: Operation not permitted
# chown: elasticsearch-7.8.1/modules/frozen-indices/NOTICE.txt: Operation not permitted
# chown: elasticsearch-7.8.1/modules/frozen-indices/LICENSE.txt: Operation not permitted
# chown: elasticsearch-7.8.1/modules/frozen-indices/frozen-indices-7.8.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/frozen-indices/plugin-descriptor.properties: Operation not permitted
# chown: elasticsearch-7.8.1/modules/frozen-indices: Operation not permitted
# chown: elasticsearch-7.8.1/modules/analysis-common/analysis-common-7.8.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/analysis-common/plugin-descriptor.properties: Operation not permitted
# chown: elasticsearch-7.8.1/modules/analysis-common: Operation not permitted
# chown: elasticsearch-7.8.1/modules/search-business-rules/search-business-rules-7.8.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/search-business-rules/NOTICE.txt: Operation not permitted
# chown: elasticsearch-7.8.1/modules/search-business-rules/LICENSE.txt: Operation not permitted
# chown: elasticsearch-7.8.1/modules/search-business-rules/plugin-descriptor.properties: Operation not permitted
# chown: elasticsearch-7.8.1/modules/search-business-rules: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-eql/x-pack-eql-7.8.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-eql/NOTICE.txt: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-eql/LICENSE.txt: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-eql/plugin-descriptor.properties: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-eql/plugin-security.policy: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-eql: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-rollup/NOTICE.txt: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-rollup/x-pack-rollup-7.8.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-rollup/LICENSE.txt: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-rollup/plugin-descriptor.properties: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-rollup/plugin-security.policy: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-rollup: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-voting-only-node/x-pack-voting-only-node-7.8.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-voting-only-node/NOTICE.txt: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-voting-only-node/LICENSE.txt: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-voting-only-node/plugin-descriptor.properties: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-voting-only-node: Operation not permitted
# chown: elasticsearch-7.8.1/modules/spatial/spatial-7.8.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/spatial/NOTICE.txt: Operation not permitted
# chown: elasticsearch-7.8.1/modules/spatial/LICENSE.txt: Operation not permitted
# chown: elasticsearch-7.8.1/modules/spatial/geo-7.8.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/spatial/plugin-descriptor.properties: Operation not permitted
# chown: elasticsearch-7.8.1/modules/spatial: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-core/transport-nio-client-7.8.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-core/httpcore-nio-4.4.12.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-core/x-pack-core-7.8.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-core/netty-codec-http-4.1.49.Final.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-core/netty-common-4.1.49.Final.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-core/netty-transport-4.1.49.Final.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-core/httpcore-4.4.12.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-core/commons-logging-1.1.3.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-core/netty-codec-4.1.49.Final.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-core/transport-netty4-client-7.8.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-core/log4j-1.2-api-2.11.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-core/NOTICE.txt: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-core/commons-codec-1.11.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-core/unboundid-ldapsdk-4.0.8.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-core/httpasyncclient-4.1.4.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-core/netty-buffer-4.1.49.Final.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-core/elasticsearch-ssl-config-7.8.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-core/httpclient-4.5.10.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-core/LICENSE.txt: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-core/elasticsearch-nio-7.8.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-core/netty-handler-4.1.49.Final.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-core/plugin-descriptor.properties: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-core/netty-resolver-4.1.49.Final.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-core/plugin-security.policy: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-core: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-enrich/NOTICE.txt: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-enrich/LICENSE.txt: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-enrich/plugin-descriptor.properties: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-enrich/x-pack-enrich-7.8.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-enrich: Operation not permitted
# chown: elasticsearch-7.8.1/modules/transform/transform-7.8.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/transform/NOTICE.txt: Operation not permitted
# chown: elasticsearch-7.8.1/modules/transform/LICENSE.txt: Operation not permitted
# chown: elasticsearch-7.8.1/modules/transform/plugin-descriptor.properties: Operation not permitted
# chown: elasticsearch-7.8.1/modules/transform: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-analytics/commons-math3-3.2.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-analytics/NOTICE.txt: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-analytics/x-pack-analytics-7.8.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-analytics/LICENSE.txt: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-analytics/plugin-descriptor.properties: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-analytics/plugin-security.policy: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-analytics: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-ilm/NOTICE.txt: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-ilm/x-pack-ilm-7.8.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-ilm/LICENSE.txt: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-ilm/plugin-descriptor.properties: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-ilm: Operation not permitted
# chown: elasticsearch-7.8.1/modules/ingest-user-agent/ingest-user-agent-7.8.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/ingest-user-agent/plugin-descriptor.properties: Operation not permitted
# chown: elasticsearch-7.8.1/modules/ingest-user-agent: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-sql/x-pack-sql-7.8.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-sql/NOTICE.txt: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-sql/sql-action-7.8.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-sql/sql-proto-7.8.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-sql/aggs-matrix-stats-client-7.8.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-sql/LICENSE.txt: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-sql/plugin-descriptor.properties: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-sql/plugin-security.policy: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-sql: Operation not permitted
# chown: elasticsearch-7.8.1/modules/aggs-matrix-stats/aggs-matrix-stats-client-7.8.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/aggs-matrix-stats/plugin-descriptor.properties: Operation not permitted
# chown: elasticsearch-7.8.1/modules/aggs-matrix-stats: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-ccr/NOTICE.txt: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-ccr/LICENSE.txt: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-ccr/x-pack-ccr-7.8.1.jar: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-ccr/plugin-descriptor.properties: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-ccr/plugin-security.policy: Operation not permitted
# chown: elasticsearch-7.8.1/modules/x-pack-ccr: Operation not permitted
# chown: elasticsearch-7.8.1/modules: Operation not permitted
# chown: elasticsearch-7.8.1: Operation not permitted

# %%
import os
from subprocess import Popen, PIPE, STDOUT

es_server = Popen(['elasticsearch-7.8.1/bin/elasticsearch'], 
                  stdout=PIPE, stderr=STDOUT)

# %%
# This part is important, since it takes a little amount of time for instance to load
import time
time.sleep(20)

# %%
# %%bash
# # If you get 1 root & 2 daemon process then Elasticsearch instance has started successfully
# ps -ef | grep elasticsearch
# Out:
#   501 33817 33813   0  6:59   ??         0:00.00 grep elasticsearch
#   501 15867 15839   0 Mer10   ttys000    2:20.87 /Users/macbookpro/Downloads/elasticsearch-7.8.1/jdk.app/Contents/Home/bin/java -Xshare:auto -Des.networkaddress.cache.ttl=60 -Des.networkaddress.cache.negative.ttl=10 -XX:+AlwaysPreTouch -Xss1m -Djava.awt.headless=true -Dfile.encoding=UTF-8 -Djna.nosys=true -XX:-OmitStackTraceInFastThrow -XX:+ShowCodeDetailsInExceptionMessages -Dio.netty.noUnsafe=true -Dio.netty.noKeySetOptimization=true -Dio.netty.recycler.maxCapacityPerThread=0 -Dio.netty.allocator.numDirectArenas=0 -Dlog4j.shutdownHookEnabled=false -Dlog4j2.disable.jmx=true -Djava.locale.providers=SPI,COMPAT -Xms1g -Xmx1g -XX:+UseG1GC -XX:G1ReservePercent=25 -XX:InitiatingHeapOccupancyPercent=30 -Djava.io.tmpdir=/var/folders/9z/vxzd5t7x2vn4503l8w3td5pm0000gn/T/elasticsearch-16399522529622432788 -XX:+HeapDumpOnOutOfMemoryError -XX:HeapDumpPath=data -XX:ErrorFile=logs/hs_err_pid%p.log -Xlog:gc*,gc+age=trace,safepoint:file=logs/gc.log:utctime,pid,tags:filecount=32,filesize=64m -XX:MaxDirectMemorySize=536870912 -Des.path.home=/Users/macbookpro/Downloads/elasticsearch-7.8.1 -Des.path.conf=/Users/macbookpro/Downloads/elasticsearch-7.8.1/config -Des.distribution.flavor=default -Des.distribution.type=tar -Des.bundled_jdk=true -cp /Users/macbookpro/Downloads/elasticsearch-7.8.1/lib/* org.elasticsearch.bootstrap.Elasticsearch
#   501 15914 15867   0 Mer10   ttys000    0:00.03 /Users/macbookpro/Downloads/elasticsearch-7.8.1/modules/x-pack-ml/platform/darwin-x86_64/controller.app/Contents/MacOS/controller

# %%
# !sudo apt-get update && sudo apt-get install ufw
# !sudo ufw disable
# Out:
# Password:
# Password:

# %%
es = Elasticsearch(hosts = [{"host":"localhost", "port":9200}])
# Check if python is connected to elasticsearch
es.ping()
# Out:
# True

# %% [markdown]
# # CLIP Image Search

# %%
INDEX_NAME = 'clip-fashion'
VECTOR_DIMS = 512

# %%
# Delete index
if es.indices.exists(index=INDEX_NAME):
  print("Index exists!")
  es.indices.delete(index=INDEX_NAME, ignore=400)
# Out:
# Index exists!

# %%
# Create index
settings = {"settings": {"number_of_shards": 2,"number_of_replicas": 1},
            "mappings": {"dynamic": "true", 
                          "_source": {"enabled": "true"},
                          "properties": {"Image_name": {"type": "text"},
                                        "Image_vector": {"type": "dense_vector", "dims": VECTOR_DIMS}
                                        }
                        }
            }


es.indices.create(index=INDEX_NAME, ignore=400, body=settings)
# Out:
# {'acknowledged': True, 'shards_acknowledged': True, 'index': 'clip-fashion'}

# %%
# Retrieve the list of index names
index_names = es.indices.get_alias("*").keys()

# Print the list of index names
print(index_names)
# Out:
# dict_keys(['clip-fashion', 'patents-bert'])

# %%
# Add image vectors to Elasticsearch
def add_image_vec(es, url):
    image = preprocess(Image.open(requests.get(url, stream=True).raw)).unsqueeze(0).to(device)

    with torch.no_grad():
        image_vector = model.encode_image(image)

    doc = {
        "Image_name": url,
        "Image_vector": np.array(image_vector.squeeze().tolist())   # convert tensor to numpy array
    }

    res = es.index(index=INDEX_NAME, body=doc)

# for url in urls:
#     print(url)
#     add_image_vec(es, url=url)
#     time.sleep(1.0)  # Add a delay of 0.5 seconds between requests

import queue

# Define queue for image URLs
url_queue = queue.Queue()

# Add image URLs to queue
for url in urls:
    url_queue.put(url)

# Process image URLs in batches
# One approach you can try is to use a Python queue to manage the image URLs and process them in batches, 
# with a delay between each batch to avoid overwhelming the Elasticsearch cluster
# by ChatGPT
batch_size = 10
while not url_queue.empty():
# https://farm66.staticflickr.com/65535/52747965135_c082cdfe39.jpg
# https://farm66.staticflickr.com/65535/52747793914_702a80604a.jpg
# https://farm66.staticflickr.com/65535/52747403566_bd0c71342e.jpg
# https://farm66.staticflickr.com/65535/52747804410_86832fa0cd.jpg
# ---------------------------------------------------------------------------
# TransportError                            Traceback (most recent call last)
# <ipython-input-41-67f42ea321ca> in <module>
#      39     for url in batch:
#      40         print(url)
# ---> 41         add_image_vec(es, url=url)
#      42
#      43     # Add a delay between batches
#
# <ipython-input-41-67f42ea321ca> in add_image_vec(es, url)
#      11     }
#      12
# ---> 13     res = es.index(index=INDEX_NAME, body=doc)
#      14
#      15 # for url in urls:
#
# ~/opt/anaconda3/envs/tf2/lib/python3.6/site-packages/elasticsearch/client/utils.py in _wrapped(*args, **kwargs)
#     137                 if p in kwargs:
#     138                     params[p] = kwargs.pop(p)
# --> 139             return func(*args, params=params, headers=headers, **kwargs)
#     140
#     141         return _wrapped
#
# ~/opt/anaconda3/envs/tf2/lib/python3.6/site-packages/elasticsearch/client/__init__.py in index(self, index, body, doc_type, id, params, headers)
#     378             params=params,
#     379             headers=headers,
# --> 380             body=body,
#     381         )
#     382
#
# ~/opt/anaconda3/envs/tf2/lib/python3.6/site-packages/elasticsearch/transport.py in perform_request(self, method, url, headers, params, body)
#     350                     headers=headers,
#     351                     ignore=ignore,
# --> 352                     timeout=timeout,
#     353                 )
#     354
#
# ~/opt/anaconda3/envs/tf2/lib/python3.6/site-packages/elasticsearch/connection/http_urllib3.py in perform_request(self, method, url, params, body, timeout, ignore, headers)
#     254                 method, full_url, url, orig_body, duration, response.status, raw_data
#     255             )
# --> 256             self._raise_error(response.status, raw_data)
#     257
#     258         self.log_request_success(
#
# ~/opt/anaconda3/envs/tf2/lib/python3.6/site-packages/elasticsearch/connection/base.py in _raise_error(self, status_code, raw_data)
#     286
#     287         raise HTTP_EXCEPTIONS.get(status_code, TransportError)(
# --> 288             status_code, error_message, additional_info
#     289         )
#     290
#
# TransportError: TransportError(429, 'cluster_block_exception', 'index [clip-fashion] blocked by: [TOO_MANY_REQUESTS/12/index read-only / allow delete (api)];')

# %%
# search for all documents in my_index
res = es.search(index=INDEX_NAME, body={'query': {'match_all': {}}})

# print the documents
for hit in res['hits']['hits']:
    print(hit['_source'])

# %%
# Query a description
import pprint

text = clip.tokenize("a man").to(device)

with torch.no_grad():
    User_Query_Vector = model.encode_text(text)

    script_query = {"script_score": {"query": {"match_all": {}},
                                    "script": {"source": "cosineSimilarity(params.query_vector, doc['Image_vector']) ",
                                              "params": {"query_vector": np.array(User_Query_Vector.squeeze().tolist()) }
                                              }
                                  }
                  }

    response = es.search(index=INDEX_NAME,body={"size": 10, "query": script_query,
                                                    "_source": {"includes": ["Image_name"]}
                                                    }
                            )


    pprint.pprint(response)

# %%
import requests

response = requests.get("http://ipecho.net/plain")
public_ip = response.text
print("Your public IP address is:", public_ip)
?
